# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from scripts.plot_profiles import plot_all_profiles

fig, axs = plot_all_profiles(T0=1e4, B=3e-6, alpha=3, v0=4e4, n0=0.1)
fig.subplots_adjust(hspace=0)

# %%
from scripts.plot_components import plot_components
fig, axs = plot_components(T0=1e4, B=3e-6, alpha=3, v0=4e4, n0=0.1)
fig.subplots_adjust(hspace = 0.01, wspace= 0.08)

# %%
# Runtime may be long due to solving multiple models
from scripts.plot_line_ratios import plot_line_ratios
fig, axs = plot_line_ratios()
